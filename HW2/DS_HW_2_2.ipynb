# %% [raw]
# Проведіть аналіз файлу 2017_jun_final.csv. Файл містить результати опитування розробників у червні 2017 року.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %% [markdown]
# - Прочитайте файл 2017_jun_final.csv за допомогою методу read_csv

# %%
data_file = pd.read_csv("data/2017_jun_final.csv", encoding='utf-8')

data_file
# Out:
#          N                 Должность Язык.программирования Специализация  \
# 0        1        Junior QA engineer                   NaN     Manual QA
# 1        2        Junior QA engineer                   NaN     Manual QA
# 2        3         Software Engineer               C#/.NET           NaN
# 3        4         Software Engineer            JavaScript           NaN
# 4        5  Senior Software Engineer            JavaScript           NaN
# ...    ...                       ...                   ...           ...
# 8699  8700               QA engineer                   NaN     Manual QA
# 8700  8701                 Marketing                   NaN           NaN
# 8701  8702  Junior Software Engineer            Ruby/Rails           NaN
# 8702  8703                 Team lead                   NaN           NaN
# 8703  8704  Senior Software Engineer                  Java           NaN
#
#      Общий.опыт.работы Опыт.работы.на.текущем.месте  Зарплата.в.месяц  \
# ...

# %% [markdown]
# - Прочитайте отриману таблицю, використовуючи метод head

# %%
data_file.head()
# Out:
#    N                 Должность Язык.программирования Специализация  \
# 0  1        Junior QA engineer                   NaN     Manual QA
# 1  2        Junior QA engineer                   NaN     Manual QA
# 2  3         Software Engineer               C#/.NET           NaN
# 3  4         Software Engineer            JavaScript           NaN
# 4  5  Senior Software Engineer            JavaScript           NaN
#
#   Общий.опыт.работы Опыт.работы.на.текущем.месте  Зарплата.в.месяц  \
# 0               0.5                          0.5               400
# 1  меньше 3 месяцев             меньше 3 месяцев               430
# 2                 4                            1              2500
# 3                 5                            4              2000
# 4    10 и более лет                          0.5              4500
#
#    Изменение.зарплаты.за.12.месяцев    Город     Размер.компании  ...  \
# 0                                 0  Харьков       до 10 человек  ...
# ...

# %% [markdown]
# - Визначте розмір таблиці за допомогою методу shape

# %%
data_file.shape
# Out:
# (8704, 25)

# %% [markdown]
# - Визначте типи всіх стовпців за допомогою dataframe.dtypes

# %%
data_file.dtypes
# Out:
# N                                     int64
# Должность                            object
# Язык.программирования                object
# Специализация                        object
# Общий.опыт.работы                    object
# Опыт.работы.на.текущем.месте         object
# Зарплата.в.месяц                      int64
# Изменение.зарплаты.за.12.месяцев      int64
# Город                                object
# Размер.компании                      object
# Тип.компании                         object
# Пол                                  object
# Возраст                               int64
# Образование                          object
# Университет                          object
# Еще.студент                            bool
# Уровень.английского                  object
# Предметная.область                   object
# Дата.заполнения                      object
# User.Agent                           object
# exp                                 float64
# ...

# %% [markdown]
# - Порахуйте, яка частка пропусків міститься в кожній колонці (використовуйте методи isnull та sum)

# %%
omissions = data_file.isnull().sum() / len(data_file)
# omissions = data_file.isnull().mean() * 100
omissions
# Out:
# N                                   0.000000
# Должность                           0.000000
# Язык.программирования               0.442325
# Специализация                       0.829389
# Общий.опыт.работы                   0.000000
# Опыт.работы.на.текущем.месте        0.000000
# Зарплата.в.месяц                    0.000000
# Изменение.зарплаты.за.12.месяцев    0.000000
# Город                               0.000000
# Размер.компании                     0.000000
# Тип.компании                        0.000000
# Пол                                 0.000000
# Возраст                             0.000000
# Образование                         0.000000
# Университет                         0.041131
# Еще.студент                         0.000000
# Уровень.английского                 0.000000
# Предметная.область                  0.025620
# Дата.заполнения                     0.000000
# User.Agent                          0.000000
# exp                                 0.000000
# ...

# %% [markdown]
# - Видаліть усі стовпці з пропусками, крім стовпця "Мова програмування"

# %%
name_save_column = 'Язык.программирования'
saved_column = data_file[name_save_column].copy()

data_file.dropna(axis=1, inplace=True)
data_file[name_save_column] = saved_column

data_file
# Out:
#          N                 Должность Общий.опыт.работы  \
# 0        1        Junior QA engineer               0.5
# 1        2        Junior QA engineer  меньше 3 месяцев
# 2        3         Software Engineer                 4
# 3        4         Software Engineer                 5
# 4        5  Senior Software Engineer    10 и более лет
# ...    ...                       ...               ...
# 8699  8700               QA engineer                 1
# 8700  8701                 Marketing               0.5
# 8701  8702  Junior Software Engineer                 1
# 8702  8703                 Team lead                 6
# 8703  8704  Senior Software Engineer                 7
#
#      Опыт.работы.на.текущем.месте  Зарплата.в.месяц  \
# 0                             0.5               400
# 1                меньше 3 месяцев               430
# 2                               1              2500
# 3                               4              2000
# ...

# %% [markdown]
# - Знову порахуйте, яка частка пропусків міститься в кожній колонці і переконайтеся, що залишився тільки стовпець "Мова.програмування"

# %%
omissions = data_file.isnull().sum() / len(data_file)

omissions
# Out:
# N                                   0.000000
# Должность                           0.000000
# Общий.опыт.работы                   0.000000
# Опыт.работы.на.текущем.месте        0.000000
# Зарплата.в.месяц                    0.000000
# Изменение.зарплаты.за.12.месяцев    0.000000
# Город                               0.000000
# Размер.компании                     0.000000
# Тип.компании                        0.000000
# Пол                                 0.000000
# Возраст                             0.000000
# Образование                         0.000000
# Еще.студент                         0.000000
# Уровень.английского                 0.000000
# Дата.заполнения                     0.000000
# User.Agent                          0.000000
# exp                                 0.000000
# current_job_exp                     0.000000
# salary                              0.000000
# Язык.программирования               0.442325
# dtype: float64

# %% [markdown]
# - Видаліть усі рядки у вихідній таблиці за допомогою методу dropna

# %%
data_file = data_file.dropna(axis=0)
data_file
# Out:
#          N                 Должность Общий.опыт.работы  \
# 2        3         Software Engineer                 4
# 3        4         Software Engineer                 5
# 4        5  Senior Software Engineer    10 и более лет
# 6        7  Junior Software Engineer                 1
# 7        8  Senior Software Engineer                 6
# ...    ...                       ...               ...
# 8692  8693         Software Engineer                 5
# 8694  8695  Junior Software Engineer                 1
# 8695  8696         Software Engineer                 1
# 8701  8702  Junior Software Engineer                 1
# 8703  8704  Senior Software Engineer                 7
#
#      Опыт.работы.на.текущем.месте  Зарплата.в.месяц  \
# 2                               1              2500
# 3                               4              2000
# 4                             0.5              4500
# 6                меньше 3 месяцев               600
# ...

# %% [markdown]
# - Визначте новий розмір таблиці за допомогою методу shape

# %%
data_file.shape
# Out:
# (4854, 20)

# %% [markdown]
# - Створіть нову таблицю python_data, в якій будуть тільки рядки зі спеціалістами, які вказали мову програмування Python

# %%
python_data = data_file[data_file['Язык.программирования'] == 'Python']

python_data
# Out:
#          N                 Должность Общий.опыт.работы  \
# 12      13         Software Engineer                 1
# 68      69         Software Engineer               1.5
# 87      88  Junior Software Engineer               0.5
# 114    115  Junior Software Engineer               1.5
# 143    144  Junior Software Engineer                 1
# ...    ...                       ...               ...
# 8546  8547         Software Engineer                 5
# 8625  8626         Software Engineer                 4
# 8635  8636  Senior Software Engineer    10 и более лет
# 8673  8674  Junior Software Engineer               0.5
# 8695  8696         Software Engineer                 1
#
#      Опыт.работы.на.текущем.месте  Зарплата.в.месяц  \
# 12               меньше 3 месяцев               800
# 68                            0.5               900
# 87                            0.5               600
# 114                           0.5               685
# ...

# %% [markdown]
# - Визначте розмір таблиці python_data за допомогою методу shape

# %%
python_data.shape
# Out:
# (207, 20)

# %% [markdown]
# - Використовуючи метод groupby, виконайте групування за стовпчиком "Посада"

# %%
position_column = 'Должность'
grouped_data = python_data.groupby(position_column)

grouped_data

# %% [markdown]
# - Створіть новий DataFrame, де для згрупованих даних за стовпчиком "Посада", виконайте агрегацію даних за допомогою методу agg і знайдіть мінімальне та максимальне значення у стовпчику "Зарплата.в.місяць"

# %%
aggregated_data = grouped_data['Зарплата.в.месяц'].agg(['min', 'max']).reset_index()
aggregated_data
# Out:
#                   Должность   min   max
# 0  Junior Software Engineer   100  1250
# 1  Senior Software Engineer  1300  9200
# 2         Software Engineer   500  5400
# 3          System Architect  3000  5000
# 4            Technical Lead  1425  6200

# %% [markdown]
# - Створіть функцію fill_avg_salary, яка повертатиме середнє значення заробітної плати на місяць. Використовуйте її для методу apply та створіть новий стовпчик "avg"

# %%
def fill_avg_salary(arg):
    return data_file['Зарплата.в.месяц'].mean()

python_data['avg'] = python_data.apply(fill_avg_salary, axis=1)

python_data
# Out:
# /tmp/ipykernel_385579/1914736796.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   python_data['avg'] = python_data.apply(fill_avg_salary, axis=1)
#          N                 Должность Общий.опыт.работы  \
# 12      13         Software Engineer                 1
# 68      69         Software Engineer               1.5
# 87      88  Junior Software Engineer               0.5
# 114    115  Junior Software Engineer               1.5
# 143    144  Junior Software Engineer                 1
# ...    ...                       ...               ...
# 8546  8547         Software Engineer                 5
# 8625  8626         Software Engineer                 4
# 8635  8636  Senior Software Engineer    10 и более лет
# ...

# %% [markdown]
# - Створіть описову статистику за допомогою методу describe для нового стовпчика.

# %%
avg_stats = python_data['avg'].describe()

avg_stats
# Out:
# count    2.070000e+02
# mean     1.883371e+03
# std      2.279249e-13
# min      1.883371e+03
# 25%      1.883371e+03
# 50%      1.883371e+03
# 75%      1.883371e+03
# max      1.883371e+03
# Name: avg, dtype: float64

# %% [markdown]
# - Збережіть отриману таблицю в CSV файл

# %%
python_data.to_csv('data/finally_data.csv', index=False)

# %% [markdown]
# -   Графік розподілу значень "avg"

# %%
plt.figure(figsize=(10, 6))
sns.histplot(avg_stats, kde=True, color='skyblue')
plt.title('Розподіл значень "avg"')
plt.xlabel('Середнє значення зарплати')
plt.ylabel('Частота')
plt.show()

# %% [markdown]
# Графік для кількості рядків у кожній категорії "Посада"

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x=position_column, data=python_data, hue=position_column, palette='dark:purple')
plt.title('Кількість рядків у кожній категорії "Посада"')
plt.xlabel('Посада')
plt.ylabel('Кількість рядків')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
